# %%
# Import setup
import pandas as pd

# %%
# Create a list containing all the files for 2022 Jersey City data
files = ["Files-CitiBikes/JC-202301-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202302-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202303-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202304-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202305-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202306-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202307-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202308-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202309-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202310-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202311-citibike-tripdata.csv",
         "Files-CitiBikes/JC-202312-citibike-tripdata.csv"]

# %%
# Create an empty dataframe to store all data
citibike_df = pd.DataFrame()

# %%
# Loop through the list of files and concatonate all data to the dataframe
for file in files:
    data = pd.read_csv(file) 
    citibike_df = pd.concat([citibike_df, data], axis=0)

# %%
files_readDF
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                 ...            ...                  ...
# 56070  17CD2F4ABD4F6785   classic_bike  2023-01-08 02:16:19
# 56071  D75D12846E6838D0  electric_bike  2023-01-21 15:32:18
# 56072  36387397177CAA80  electric_bike  2023-01-29 14:01:15
# 56073  B66278F45420CFA0   classic_bike  2023-01-30 08:28:41
# 56074  230153A8D1F2D5F7   classic_bike  2023-01-28 17:53:21
#
#                   ended_at                            start_station_name  \
# 0      2023-01-28 09:28:52      Hoboken Terminal - Hudson St & Hudson Pl
# 1      2023-01-23 20:18:27      Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
# Store the dataframe as CSV file
citibike_df.to_csv('Files-CitiBikes/2023jc_data.csv', index=False)
